# %%
# !git clone https://github.com/Edwarddev0723/MureObjectStitch-Image-Composition.git
# Out:
# Cloning into 'MureObjectStitch-Image-Composition'...
# remote: Enumerating objects: 295, done.
# remote: Counting objects: 100% (295/295), done.
# remote: Compressing objects: 100% (240/240), done.
# remote: Total 295 (delta 61), reused 219 (delta 33), pack-reused 0 (from 0)
# Receiving objects: 100% (295/295), 22.10 MiB | 10.29 MiB/s, done.
# Resolving deltas: 100% (61/61), done.

# %%
from transformers import CLIPProcessor, CLIPModel
import os

# 指定模型下載的目標資料夾
custom_cache_dir = "/content/MureObjectStitch-Image-Composition/checkpoints"

# 如果資料夾不存在，建立資料夾
os.makedirs(custom_cache_dir, exist_ok=True)

# 下載模型到指定資料夾
model_name = "openai/clip-vit-large-patch14"
model = CLIPModel.from_pretrained(model_name, cache_dir=custom_cache_dir)
processor = CLIPProcessor.from_pretrained(model_name, cache_dir=custom_cache_dir)

print(f"Model and processor downloaded to: {custom_cache_dir}")
# Out:
# config.json:   0%|          | 0.00/4.52k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.71G [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/905 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/961k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# Model and processor downloaded to: /content/MureObjectStitch-Image-Composition/checkpoints

# %%
import requests
import os

# 檔案 URL
url = "https://huggingface.co/BCMIZB/Libcom_pretrained_models/resolve/main/ObjectStitch.pth"

# 設定儲存的目標資料夾與檔案名稱
destination_folder = "/content/MureObjectStitch-Image-Composition/checkpoints"
file_name = "ObjectStitch.pth"  # 加入檔案名稱

# 確保目標資料夾存在
#os.makedirs(destination_folder, exist_ok=True)

# 設定檔案完整儲存路徑
destination_path = os.path.join(destination_folder, file_name)

# 下載檔案
print("Downloading file...")
response = requests.get(url, stream=True)
if response.status_code == 200:
    with open(destination_path, 'wb') as file:
        for chunk in response.iter_content(chunk_size=8192):
            if chunk:
                file.write(chunk)
    print(f"檔案已成功下載至 {destination_path}")
else:
    print(f"下載失敗，HTTP 狀態碼: {response.status_code}")
# Out:
# ...
# 檔案已成功下載至 /content/MureObjectStitch-Image-Composition/checkpoints/ObjectStitch.pth

# %%
# !pip install pip==24.0
# !pip install pytorch-lightning==1.8.1
# !pip install omegaconf==2.3.0
# Out:
# ...
# DEPRECATION: pytorch-lightning 1.8.1 has a non-standard dependency specifier torch>=1.9.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# ...
# DEPRECATION: pytorch-lightning 1.8.1 has a non-standard dependency specifier torch>=1.9.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# ...

# %%
# %cd /content/MureObjectStitch-Image-Composition
# Out:
# /content/MureObjectStitch-Image-Composition

# %%
# %cd src/taming-transformers
# !pip install -e .
# Out:
# /content/MureObjectStitch-Image-Composition/src/taming-transformers
# Obtaining file:///content/MureObjectStitch-Image-Composition/src/taming-transformers
#   Preparing metadata (setup.py) ... done
# ...
# DEPRECATION: pytorch-lightning 1.8.1 has a non-standard dependency specifier torch>=1.9.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# ...
#   Running setup.py develop for taming-transformers
# ...

# %%
# %cd ..
# %cd ..
# Out:
# /content/MureObjectStitch-Image-Composition/src
# /content/MureObjectStitch-Image-Composition

# %%
# !pip install clip
# Out:
# ...
# DEPRECATION: pytorch-lightning 1.8.1 has a non-standard dependency specifier torch>=1.9.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
# !pip install openimages
# Out:
# ...
# DEPRECATION: pytorch-lightning 1.8.1 has a non-standard dependency specifier torch>=1.9.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# ...

# %%
# !oi_download_images --base_dir ./openimages --labels Scissors --limit 4
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/oi_download_images", line 8, in <module>
#     sys.exit(_entrypoint_download_images())
#   File "/usr/local/lib/python3.10/dist-packages/openimages/download.py", line 850, in _entrypoint_download_images
#     download_images(
#   File "/usr/local/lib/python3.10/dist-packages/openimages/download.py", line 250, in download_images
#     image_directories = download_dataset(
#   File "/usr/local/lib/python3.10/dist-packages/openimages/download.py", line 133, in download_dataset
#     label_codes = _class_label_codes(class_labels, csv_dir)
#   File "/usr/local/lib/python3.10/dist-packages/openimages/download.py", line 65, in _class_label_codes
#     raise ValueError(
# ValueError: Failed to get class descriptions information -- Invalid response (status code: 403) from https://storage.googleapis.com/openimages/v5/class-descriptions-boxable.csv

# %%
# !oi_download_images --base_dir ./data --labels /m/04dr76w --limit 40
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/oi_download_images", line 8, in <module>
#     sys.exit(_entrypoint_download_images())
#   File "/usr/local/lib/python3.10/dist-packages/openimages/download.py", line 850, in _entrypoint_download_images
#     download_images(
#   File "/usr/local/lib/python3.10/dist-packages/openimages/download.py", line 250, in download_images
#     image_directories = download_dataset(
#   File "/usr/local/lib/python3.10/dist-packages/openimages/download.py", line 133, in download_dataset
#     label_codes = _class_label_codes(class_labels, csv_dir)
#   File "/usr/local/lib/python3.10/dist-packages/openimages/download.py", line 65, in _class_label_codes
#     raise ValueError(
# ValueError: Failed to get class descriptions information -- Invalid response (status code: 403) from https://storage.googleapis.com/openimages/v5/class-descriptions-boxable.csv

# %%
import torchvision
from torchvision import datasets



# 下載 COCO Dataset
coco_dataset = datasets.CocoDetection(root='/content/MureObjectStitch-Image-Composition/data', annFile='./data/annotations/instances_val2017.json', d)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!

# %%
# !pip install torch==1.9.0 torchvision==0.10.0 torchaudio==0.9.0
# Out:
# ERROR: Could not find a version that satisfies the requirement torch==1.9.0 (from versions: 1.11.0, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1)
# ERROR: No matching distribution found for torch==1.9.0

# %%
# !python scripts/inference.py \
--outdir results \
--testdir examples/example1 \
--num_samples 5 \
--sample_steps 50 \
--gpu 0
# Out:
# Traceback (most recent call last):
#   File "/content/MureObjectStitch-Image-Composition/scripts/inference.py", line 1, in <module>
#     from ldm.data.open_images import get_tensor, get_tensor_clip, get_bbox_tensor, bbox2mask, mask2bbox
# ModuleNotFoundError: No module named 'ldm'

# %%
# %%sh finetune.sh
# Out:
# Running on GPUs 1
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.54 M params.
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 4, 64, 64) = 16384 dimensions.
# making attention of type 'vanilla' with 512 in_channels
# FrozenCLIPImageEmbedder has 366.16 M params.
# Load  /content/MureObjectStitch-Image-Composition/checkpoints/ObjectStitch.pth
# Monitoring val/loss_simple_ema as checkpoint metric.
# Merged modelckpt-cfg:
# {'target': 'pytorch_lightning.callbacks.ModelCheckpoint', 'params': {'dirpath': '/content/MureObjectStitch-Image-Composition/experiments/objectstitch/2025-01-09T07-48-32_car_multifg/checkpoints', 'filename': '{epoch:06}', 'verbose': True, 'save_last': False, 'save_weights_only': True, 'monitor': 'val/loss_simple_ema', 'save_top_k': 5}}
# Caution: Saving checkpoints every n train steps without deleting. This might require some free space.
# #### Data #####
# train, MureComDataset, 0
# ...

# %%
# !python main.py \
  --logdir experiments/objectstitch \
  --name='car_multifg' \
  --num_workers 4 \
  --devices 1 \
  --batch_size 1 \
  --num_nodes 1 \
  --base configs/murecom.yaml \
  --package_name='Car' \
  --fg_name='fg1' \
# Out:
# 2025-01-09 07:50:32.232558: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-09 07:50:32.256959: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-09 07:50:32.264302: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-09 07:50:32.282504: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
import pytorch_lightning
print(pytorch_lightning.__version__)
# Out:
# 1.8.1

# %%
import os

from shutil import copyfile
from pycocotools.coco import COCO
from xml.dom.minidom import parseString
from lxml.etree import Element, SubElement, tostring
from IPython.display import clear_output

def update_progress(progress):
    bar_length = 20
    if isinstance(progress, int):
        progress = float(progress)
    if not isinstance(progress, float):
        progress = 0
    if progress < 0:
        progress = 0
    if progress >= 1:
        progress = 1
    block = int(round(bar_length * progress))
    clear_output(wait = True)
    text = "Progress: [{0}] {1:.1f}%".format( "#" * block + "-" * (bar_length - block), progress * 100)
    print(text)

current_path = os.path.abspath(os.getcwd())

COCO_ANNOTATIONS_PATH = current_path + "\\annotations\\instances_train2017.json"
COCO_IMAGES_DIRECTORY = current_path + "\\train2017\\"
EXTRACTED_SAVING_PATH = current_path + "\\extracted_dataset\\"
SAVE_FOLDER = EXTRACTED_SAVING_PATH.split('\\')[len(EXTRACTED_SAVING_PATH.split('\\'))-2]

if not os.path.exists(EXTRACTED_SAVING_PATH):
    os.mkdir(EXTRACTED_SAVING_PATH)

coco = COCO(COCO_ANNOTATIONS_PATH)

cats = coco.loadCats(coco.getCatIds())

nms=[cat['name'] for cat in cats]

target_classes = []
with open(current_path + '/classes.txt', 'r') as f:
    for line in f.readlines():
        target_classes.append(line.strip())

img_dict = {}
for classes in target_classes:
    catIds = coco.getCatIds(catNms=[classes])
    imgIds = coco.getImgIds(catIds=catIds)
    for imgID in imgIds:
        try:
            content = ''
            content = img_dict[imgID] + ','
        except:
            pass
        img_dict[imgID] = content + classes

total_progress = len(img_dict)
progress = 0

for img_id in img_dict:
    progress +=1
    annotation_ids = coco.getAnnIds(img_id)
    annotations = coco.loadAnns(annotation_ids)

    image_meta = coco.loadImgs(annotations[0]["image_id"])[0]
    node_root = Element('annotation')
    node_folder = SubElement(node_root, 'folder')
    node_folder.text = SAVE_FOLDER
    node_filename = SubElement(node_root, 'filename')
    node_filename.text = image_meta['file_name']
    node_size = SubElement(node_root, 'size')
    node_width = SubElement(node_size, 'width')
    node_width.text = str(image_meta['width'])
    node_height = SubElement(node_size, 'height')
    node_height.text = str(image_meta['height'])
    node_depth = SubElement(node_size, 'depth')
    node_depth.text = '3'

    for i in range(len(annotations)):
        entity_id = annotations[i]["category_id"]
        entity = coco.loadCats(entity_id)[0]["name"]
        if entity in target_classes:
            node_object = SubElement(node_root, 'object')
            node_name = SubElement(node_object, 'name')
            node_name.text = entity
            node_difficult = SubElement(node_object, 'difficult')
            node_difficult.text = '0'
            node_bndbox = SubElement(node_object, 'bndbox')
            node_xmin = SubElement(node_bndbox, 'xmin')
            node_xmin.text = str(round(annotations[i]['bbox'][0]))
            node_ymin = SubElement(node_bndbox, 'ymin')
            node_ymin.text = str(round(annotations[i]['bbox'][1]))
            node_xmax = SubElement(node_bndbox, 'xmax')
            node_xmax.text = str(round(annotations[i]['bbox'][0]+annotations[i]['bbox'][2]))
            node_ymax = SubElement(node_bndbox, 'ymax')
            node_ymax.text = str(round(annotations[i]['bbox'][1]+annotations[i]['bbox'][3]))

    xml = tostring(node_root, pretty_print=True)
    dom = parseString(xml)
    with open( EXTRACTED_SAVING_PATH + image_meta['file_name'].split('.')[0] + '.xml','w') as xml_file:
        xml_file.write(dom.toxml())

    copyfile(COCO_IMAGES_DIRECTORY + image_meta['file_name'],
             EXTRACTED_SAVING_PATH + image_meta['file_name'])

    update_progress(progress/total_progress)
# Out:
# loading annotations into memory...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-22a2ca974bcf> in <cell line: 34>()
#      32     os.mkdir(EXTRACTED_SAVING_PATH)
#      33
# ---> 34 coco = COCO(COCO_ANNOTATIONS_PATH)
#      35
#      36 cats = coco.loadCats(coco.getCatIds())
#
# /usr/local/lib/python3.10/dist-packages/pycocotools/coco.py in __init__(self, annotation_file)
#      79             print('loading annotations into memory...')
#      80             tic = time.time()
# ---> 81             with open(annotation_file, 'r') as f:
#      82                 dataset = json.load(f)
#      83             assert type(dataset)==dict, 'annotation file format {} not supported'.format(type(dataset))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/MureObjectStitch-Image-Composition\\annotations\\instances_train2017.json'
